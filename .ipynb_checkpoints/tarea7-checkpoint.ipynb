# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
st = pd.read_csv("euroo.csv", index_col = "Date", parse_dates = True)
st.head()
# Out:
#               Price     Open     High      Low Change %
# Date
# 2018-11-05  22.8542  22.8237  22.8561  22.8109    0.13%
# 2018-11-04  22.8237  22.8030  22.8521  22.8030    0.05%
# 2018-11-02  22.8121  22.9957  23.0576  22.7664   -0.80%
# 2018-11-01  22.9965  23.0065  23.0683  22.8482   -0.05%
# 2018-10-31  23.0073  22.7481  23.1703  22.6977    1.14%

# %%
st["Price"].plot(figsize=(20,10))

# %%
st["Price"].describe()
# Out:
# count    803.000000
# mean      21.373007
# std        1.308786
# min       17.510100
# 25%       20.525900
# 50%       21.395900
# 75%       22.336750
# max       24.339500
# Name: Price, dtype: float64

# %%
tsd = st["Price"].groupby(pd.TimeGrouper(freq='M')).agg('mean')
# Out:
# /home/sandy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.TimeGrouper is deprecated and will be removed; Please use pd.Grouper(freq=...)
#   """Entry point for launching an IPython kernel.

# %%
tsd.describe()
# Out:
# count    37.000000
# mean     21.346378
# std       1.332200
# min      17.749800
# 25%      20.542686
# 50%      21.531577
# 75%      22.217178
# max      23.693920
# Name: Price, dtype: float64

# %%
tsd.plot(figsize=(20,10))

# %%
import statsmodels.api as sm
sm.stats.durbin_watson(tsd)
# Out:
# 0.0009463978785685428

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(tsd, order=(4,0,2))
model_fit = model.fit()
# Out:
# /home/sandy/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
pred = model_fit.predict(start='2018-11', end='2019-06')

# %%
tsd.plot(figsize=(20,10))
pred.plot(figsize=(20,10))
plt.show()

print(pred.head())
print(tsd.head())
# Out:
# 2018-11-30    21.909525
# 2018-12-31    22.237543
# 2019-01-31    22.615217
# 2019-02-28    22.528901
# 2019-03-31    22.095285
# Freq: M, dtype: float64
# Date
# 2015-11-30    17.749800
# 2015-12-31    18.611891
# 2016-01-31    19.623914
# 2016-02-29    20.506333
# 2016-03-31    19.621204
# Freq: M, Name: Price, dtype: float64
